# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot
from sklearn.model_selection import train_test_split

# %%
images = pd.read_csv(r"C:\Users\magnu\Desktop\D7041E_FER\datasets\icml_face_data.csv")

# %%
label_to_text = {0:'anger', 1:'disgust', 2:'fear', 3:'happines', 4:'sadness', 5:'surprise', 6:'neutral'}

# %%
images.columns
# Out:
# Index(['emotion', 'Usage', 'pixels'], dtype='object')

# %%
np.array(images.pixels.loc[0].split(' ')).reshape(48, 48)
# Out:
# array([['70', '80', '82', ..., '52', '43', '41'],
#        ['65', '61', '58', ..., '56', '52', '44'],
#        ['50', '43', '54', ..., '49', '56', '47'],
#        ...,
#        ['91', '65', '42', ..., '72', '56', '43'],
#        ['77', '82', '79', ..., '105', '70', '46'],
#        ['77', '72', '84', ..., '106', '109', '82']], dtype='<U3')

# %%
fig = pyplot.figure(1, (14, 14))
k=0
for label in sorted(images.emotion.unique()):
    for j in range(3):
        px = images[images.emotion==label].pixels.iloc[k]
        px = np.array(px.split(' ')).reshape(48, 48).astype('float32')
        k += 1
        ax = pyplot.subplot(7, 7, k)
        ax.imshow(px)
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[label])
        pyplot.tight_layout()

# %%
image_array = images.pixels.apply(lambda x : np.array(x.split(' ')).reshape(48, 48, 1).astype('float32'))

# %%
image_array = np.stack(image_array, axis=0)

# %%
labels = images.emotion.values

# %%
#We have found that the test size works best at 0.1 rather than 0.2
X_train, X_test, y_train, y_test = train_test_split(image_array, labels, test_size=0.1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((32298, 48, 48, 1), (3589, 48, 48, 1), (32298,), (3589,))

# %%
X_train = X_train/255
X_test = X_test/255

# %%
#0.56811 validation accuracy. With 50 epochs and 0.2 in validation split. Sparse categorical loss function. 
#Adam optimizer. learning rate 0.0001
def third_cnn():
    
    model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape = (48, 48, 1)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    tf.keras.layers.BatchNormalization(),    
                                    
                                    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape = (48, 48, 1)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    tf.keras.layers.BatchNormalization(), 
                                    
                                    tf.keras.layers.Conv2D(128, (3,3), activation='relu', input_shape = (48, 48, 1)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    tf.keras.layers.BatchNormalization(), 
                                    
                                    tf.keras.layers.Conv2D(256, (3,3), activation='relu', input_shape = (48, 48, 1)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    tf.keras.layers.BatchNormalization(), 
                                    
                                    
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(4096, activation='relu'),
                                    tf.keras.layers.Dense(7, activation='softmax')
                                    
                                    
                                   ])

    return model

model = third_cnn()

# %%
#Adam as an optimizer has been found to be the best and using 0.001 is the most fitting learning rate for 50 epochs.
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss = ('sparse_categorical_crossentropy'), metrics = ['accuracy'])

# %%
file_name = 'best_model.h5'
checkpoint_path = os.path.join('checkpoint',file_name)

call_back = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                              monitor='val_accuracy',
                                              verbose=1,
                                              save_freq='epoch',
                                              save_best_only=True,
                                              save_weights_only=False,
                                              mode='max')

# %%
#You can cancel the running of this line and still have the best epoch saved
model.fit(X_train, y_train, epochs=50, validation_split=0.2, callbacks=call_back)
# Out:
# Epoch 1/50
# 808/808 [==============================] - ETA: 0s - loss: 1.6937 - accuracy: 0.3730
# Epoch 1: val_accuracy improved from -inf to 0.43529, saving model to checkpoint\best_model.h5
# 808/808 [==============================] - 214s 263ms/step - loss: 1.6937 - accuracy: 0.3730 - val_loss: 1.4357 - val_accuracy: 0.4353
# Epoch 2/50
# 808/808 [==============================] - ETA: 0s - loss: 1.3725 - accuracy: 0.4761
# Epoch 2: val_accuracy improved from 0.43529 to 0.51548, saving model to checkpoint\best_model.h5
# 808/808 [==============================] - 220s 272ms/step - loss: 1.3725 - accuracy: 0.4761 - val_loss: 1.2798 - val_accuracy: 0.5155
# Epoch 3/50
# 807/808 [============================>.] - ETA: 0s - loss: 1.2484 - accuracy: 0.5270
# Epoch 3: val_accuracy improved from 0.51548 to 0.54752, saving model to checkpoint\best_model.h5
# 808/808 [==============================] - 211s 262ms/step - loss: 1.2483 - accuracy: 0.5269 - val_loss: 1.2046 - val_accuracy: 0.5475
# Epoch 4/50
# 808/808 [==============================] - ETA: 0s - loss: 1.1621 - accuracy: 0.5554
# Epoch 4: val_accuracy did not improve from 0.54752
# 808/808 [==============================] - 196s 242ms/step - loss: 1.1621 - accuracy: 0.5554 - val_loss: 1.2148 - val_accuracy: 0.5413
# Epoch 5/50
# 808/808 [==============================] - ETA: 0s - loss: 1.0774 - accuracy: 0.5890
# Epoch 5: val_accuracy improved from 0.54752 to 0.57492, saving model to checkpoint\best_model.h5
# 808/808 [==============================] - 211s 261ms/step - loss: 1.0774 - accuracy: 0.5890 - val_loss: 1.1450 - val_accuracy: 0.5749
# Epoch 6/50
# 808/808 [==============================] - ETA: 0s - loss: 1.0068 - accuracy: 0.6194
# Epoch 6: val_accuracy did not improve from 0.57492
# 808/808 [==============================] - 202s 251ms/step - loss: 1.0068 - accuracy: 0.6194 - val_loss: 1.1630 - val_accuracy: 0.5655
# Epoch 7/50
# 808/808 [==============================] - ETA: 0s - loss: 0.9317 - accuracy: 0.6454
# Epoch 7: val_accuracy did not improve from 0.57492
# 808/808 [==============================] - 211s 261ms/step - loss: 0.9317 - accuracy: 0.6454 - val_loss: 1.1417 - val_accuracy: 0.5701
# Epoch 8/50
# 808/808 [==============================] - ETA: 0s - loss: 0.8773 - accuracy: 0.6683
# Epoch 8: val_accuracy did not improve from 0.57492
# 808/808 [==============================] - 212s 263ms/step - loss: 0.8773 - accuracy: 0.6683 - val_loss: 1.1751 - val_accuracy: 0.5548
# Epoch 9/50
# 808/808 [==============================] - ETA: 0s - loss: 0.8108 - accuracy: 0.6968
# Epoch 9: val_accuracy did not improve from 0.57492
# 808/808 [==============================] - 214s 265ms/step - loss: 0.8108 - accuracy: 0.6968 - val_loss: 1.1920 - val_accuracy: 0.5698
# Epoch 10/50
# 808/808 [==============================] - ETA: 0s - loss: 0.7533 - accuracy: 0.7172
# Epoch 10: val_accuracy improved from 0.57492 to 0.58251, saving model to checkpoint\best_model.h5
# 808/808 [==============================] - 218s 270ms/step - loss: 0.7533 - accuracy: 0.7172 - val_loss: 1.1395 - val_accuracy: 0.5825
# Epoch 11/50
# 808/808 [==============================] - ETA: 0s - loss: 0.6882 - accuracy: 0.7410
# Epoch 11: val_accuracy improved from 0.58251 to 0.58870, saving model to checkpoint\best_model.h5
# 808/808 [==============================] - 227s 281ms/step - loss: 0.6882 - accuracy: 0.7410 - val_loss: 1.1531 - val_accuracy: 0.5887
# Epoch 12/50
# 808/808 [==============================] - ETA: 0s - loss: 0.6306 - accuracy: 0.7638
# Epoch 12: val_accuracy did not improve from 0.58870
# 808/808 [==============================] - 225s 278ms/step - loss: 0.6306 - accuracy: 0.7638 - val_loss: 1.2081 - val_accuracy: 0.5780
# Epoch 13/50
# 808/808 [==============================] - ETA: 0s - loss: 0.5917 - accuracy: 0.7795
# Epoch 13: val_accuracy improved from 0.58870 to 0.58978, saving model to checkpoint\best_model.h5
# 808/808 [==============================] - 226s 280ms/step - loss: 0.5917 - accuracy: 0.7795 - val_loss: 1.2567 - val_accuracy: 0.5898
# Epoch 14/50
# 808/808 [==============================] - ETA: 0s - loss: 0.5522 - accuracy: 0.7995
# Epoch 14: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 211s 261ms/step - loss: 0.5522 - accuracy: 0.7995 - val_loss: 1.2688 - val_accuracy: 0.5724
# Epoch 15/50
# 808/808 [==============================] - ETA: 0s - loss: 0.5197 - accuracy: 0.8092
# Epoch 15: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 190s 235ms/step - loss: 0.5197 - accuracy: 0.8092 - val_loss: 1.3411 - val_accuracy: 0.5593
# Epoch 16/50
# 808/808 [==============================] - ETA: 0s - loss: 0.4787 - accuracy: 0.8227
# Epoch 16: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 200s 248ms/step - loss: 0.4787 - accuracy: 0.8227 - val_loss: 1.5072 - val_accuracy: 0.5246
# Epoch 17/50
# 808/808 [==============================] - ETA: 0s - loss: 0.4507 - accuracy: 0.8353
# Epoch 17: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 226s 279ms/step - loss: 0.4507 - accuracy: 0.8353 - val_loss: 1.4021 - val_accuracy: 0.5680
# Epoch 18/50
# 808/808 [==============================] - ETA: 0s - loss: 0.4196 - accuracy: 0.8460
# Epoch 18: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 231s 286ms/step - loss: 0.4196 - accuracy: 0.8460 - val_loss: 1.4616 - val_accuracy: 0.5666
# Epoch 19/50
# 808/808 [==============================] - ETA: 0s - loss: 0.3967 - accuracy: 0.8578
# Epoch 19: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 226s 279ms/step - loss: 0.3967 - accuracy: 0.8578 - val_loss: 1.4136 - val_accuracy: 0.5862
# Epoch 20/50
# 808/808 [==============================] - ETA: 0s - loss: 0.3794 - accuracy: 0.8640
# Epoch 20: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 237s 293ms/step - loss: 0.3794 - accuracy: 0.8640 - val_loss: 1.4511 - val_accuracy: 0.5525
# Epoch 21/50
# 808/808 [==============================] - ETA: 0s - loss: 0.3536 - accuracy: 0.8713
# Epoch 21: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 228s 282ms/step - loss: 0.3536 - accuracy: 0.8713 - val_loss: 1.4583 - val_accuracy: 0.5676
# Epoch 22/50
# 808/808 [==============================] - ETA: 0s - loss: 0.3496 - accuracy: 0.8731
# Epoch 22: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 213s 264ms/step - loss: 0.3496 - accuracy: 0.8731 - val_loss: 1.4807 - val_accuracy: 0.5875
# Epoch 23/50
# 808/808 [==============================] - ETA: 0s - loss: 0.3231 - accuracy: 0.8849
# Epoch 23: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 235s 291ms/step - loss: 0.3231 - accuracy: 0.8849 - val_loss: 1.5125 - val_accuracy: 0.5517
# Epoch 24/50
# 808/808 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 0.8870
# Epoch 24: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 235s 291ms/step - loss: 0.3104 - accuracy: 0.8870 - val_loss: 1.4826 - val_accuracy: 0.5735
# Epoch 25/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2933 - accuracy: 0.8960
# Epoch 25: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 266s 330ms/step - loss: 0.2933 - accuracy: 0.8960 - val_loss: 1.4995 - val_accuracy: 0.5728
# Epoch 26/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2837 - accuracy: 0.8985
# Epoch 26: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 255s 316ms/step - loss: 0.2837 - accuracy: 0.8985 - val_loss: 1.5693 - val_accuracy: 0.5624
# Epoch 27/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2815 - accuracy: 0.8979
# Epoch 27: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 265s 328ms/step - loss: 0.2815 - accuracy: 0.8979 - val_loss: 1.6792 - val_accuracy: 0.5602
# Epoch 28/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2615 - accuracy: 0.9060
# Epoch 28: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 263s 325ms/step - loss: 0.2615 - accuracy: 0.9060 - val_loss: 1.6758 - val_accuracy: 0.5686
# Epoch 29/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2449 - accuracy: 0.9123
# Epoch 29: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 268s 331ms/step - loss: 0.2449 - accuracy: 0.9123 - val_loss: 1.7133 - val_accuracy: 0.5842
# Epoch 30/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.9155
# Epoch 30: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 271s 335ms/step - loss: 0.2411 - accuracy: 0.9155 - val_loss: 1.6489 - val_accuracy: 0.5728
# Epoch 31/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2339 - accuracy: 0.9202
# Epoch 31: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 241s 298ms/step - loss: 0.2339 - accuracy: 0.9202 - val_loss: 1.7182 - val_accuracy: 0.5856
# Epoch 32/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2357 - accuracy: 0.9166
# Epoch 32: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 223s 276ms/step - loss: 0.2357 - accuracy: 0.9166 - val_loss: 1.7569 - val_accuracy: 0.5754
# Epoch 33/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2168 - accuracy: 0.9215
# Epoch 33: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 228s 282ms/step - loss: 0.2168 - accuracy: 0.9215 - val_loss: 1.8136 - val_accuracy: 0.5728
# Epoch 34/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9282
# Epoch 34: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 309s 383ms/step - loss: 0.2106 - accuracy: 0.9282 - val_loss: 1.7492 - val_accuracy: 0.5751
# Epoch 35/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2070 - accuracy: 0.9275
# Epoch 35: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 269s 332ms/step - loss: 0.2070 - accuracy: 0.9275 - val_loss: 1.7923 - val_accuracy: 0.5632
# Epoch 36/50
# 808/808 [==============================] - ETA: 0s - loss: 0.2038 - accuracy: 0.9282
# Epoch 36: val_accuracy did not improve from 0.58978
# 808/808 [==============================] - 278s 344ms/step - loss: 0.2038 - accuracy: 0.9282 - val_loss: 1.8006 - val_accuracy: 0.5715
# Epoch 37/50
# 558/808 [===================>..........] - ETA: 1:30 - loss: 0.1817 - accuracy: 0.9372

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
final_model = tf.keras.models.load_model(checkpoint_path)
from IPython.display import clear_output
import time
for k in range(50):
    print(f'actual label is {label_to_text[y_test[k]]}')
    predicted_class = final_model.predict(tf.expand_dims(X_test[k], 0)).argmax()
    print(f'predicted label is {label_to_text[predicted_class]}')
    pyplot.imshow(X_test[k].reshape(48,48))
    pyplot.show()
    time.sleep(3)
    clear_output(wait=True)

# %% [markdown]
# # Earlier versions of the CNN model and their test results

# %%
#0.54536 validation accuracy. With 50 epochs and 0.2 in validation split. Sparse categorical loss function. 
#RMSprop optimizer. learning rate 0.0001

#0.56718 validation accuracy. With 50 epochs and 0.2 in validation split. Sparse categorical loss function. 
#Adam optimizer. learning rate 0.0001
model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape = (48, 48, 1)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    
                                    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape = (48, 48, 1)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    
                                    tf.keras.layers.Conv2D(128, (3,3), activation='relu', input_shape = (48, 48, 1)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    
                                    tf.keras.layers.Conv2D(256, (3,3), activation='relu', input_shape = (48, 48, 1)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    
                                    
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(4096, activation='relu'),
                                    tf.keras.layers.Dense(7, activation='softmax')
                                    
                                    
                                   ])

# %%
#0.54536 validation accuracy. With 50 epochs and 0.2 in validation split. Sparse categorical loss function. 
#RMSprop optimizer. learning rate 0.0001

#0.55851 validation accuracy. With 50 epochs and 0.2 in validation split. Sparse categorical loss function. 
#Adam optimizer. learning rate 0.0001


#0.39133 validation accuracy. With 50 epochs and 0.2 in validation split. Sparse categorical loss function. 
#Adam optimizer. learning rate 0.0001
def fer_improved_cnn():

    model = tf.keras.models.Sequential()

    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)))

    model.add(tf.keras.layers.BatchNormalization())

    model.add(tf.keras.layers.MaxPooling2D((2, 2)))

    model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))

    model.add(tf.keras.layers.BatchNormalization())

    model.add(tf.keras.layers.MaxPooling2D((2, 2)))

    model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu'))

    model.add(tf.keras.layers.BatchNormalization())

    model.add(tf.keras.layers.Flatten())

    model.add(tf.keras.layers.Dropout(0.5))

    model.add(tf.keras.layers.Dense(64, activation='relu'))

    model.add(tf.keras.layers.Dense(7, activation='softmax'))

    return model

model = fer_improved_cnn()
